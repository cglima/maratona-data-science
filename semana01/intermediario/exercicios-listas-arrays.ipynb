# %% [markdown]
# **Exercícios**
#
# 1. Crie uma lista vazia. Receba de um input do usuário 3 números e os adicione em sua lista. Printe por fim sua lista.
#
# 2. Com a lista dos números, ordene-os com algum método listado em dir(list).
#
# 3. Crie uma lista vazia. Receba do usuário, através de inputs, 3 palavras. Apresente-as em ordem alfabética inversa (de Z à A).

# %% [markdown]
# **Exercício 1**

# %%
lista = []
print(type(lista))

numero1 = int(input("Digite um número inteiro: "))
lista.append([numero1])
numero2 = int(input("Digite outro número inteiro: "))
lista.append([numero2])
numero3 = int(input("Digite outro número inteiro: "))
lista.append([numero3])
# Out:
# <class 'list'>
# Digite um número inteiro: 4
# Digite outro número inteiro: 7
# Digite outro número inteiro: -1

# %% [markdown]
# **Exercício 2**

# %%
dir(list)
lista.sort()
print(lista)
# Out:
# [-1, 4, 7]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %% [markdown]
# **Exercício 3**

# %%
lista = [] 
palavra1 = input("Digite uma palavra: ")
lista.append(palavra1)
palavra2 = input("Digite mais uma palavra: ")
lista.append(palavra2)
palavra3 = input("Digite só mais uma palavra: ")
lista.append(palavra3)

lista.sort(reverse=True)
#lista.reverse()

print(lista)
# Out:
# Digite uma palavra: cadeira
# Digite mais uma palavra: zoologico
# Digite só mais uma palavra: lapis
# ['cadeira', 'lapis', 'zoologico']
